# %% [markdown]
# ## Display a GIF
#
# Included here are two ways to display a animated gif or other movie file in a python notebook.
#
# ![CMoore orbit](testfile.gif) <center>moving sine function animated gif</center>

# %%
# %matplotlib inline

#from ipywidgets import interact, interactive, widgets
#from ipywidgets import Image
from IPython.display import display, Image

# %%
# Display the animation
with open('testfile.gif','rb') as file:
    display(Image(file.read()))
